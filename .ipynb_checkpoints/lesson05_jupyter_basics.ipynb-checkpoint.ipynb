# %% [markdown]
# # Lesson 05 — Jupyter Notebooks
#
# Testing Markdown, code cells, magic commands, NumPy and Matplotlib.

# %%
# Подключаем NumPy для работы с массивами
import numpy as np

# Создаём массив из 1000 случайных чисел
data = np.random.randn(1000)

# Считаем среднее и стандартное отклонение
data.mean(), data.std()
# Out:
# (np.float64(-0.0023485205788067462), np.float64(0.9986975046553617))

# %%
# Магическая команда Jupyter: много раз запускает код и считает среднее время
# %timeit np.random.randn(100000)
# Out:
# 993 μs ± 6.96 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# Включает отображение графиков прямо внутри notebook
# %matplotlib inline

# Подключаем matplotlib
import matplotlib.pyplot as plt

# Строим простой график
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()# Включает отображение графиков прямо внутри notebook
# %matplotlib inline

# Подключаем matplotlib
import matplotlib.pyplot as plt

# Строим простой график
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()
